# %% [markdown]
# <a href="https://colab.research.google.com/github/kfahn22/julia_kaleidoscope/blob/main/push_kaleidescope_data_to_HF_hub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uploading a dataset to the Hugging Face Hub
#
# This notebook demonstrates how to push a dataset generated in P5.js to the Hugging Face Hub. The images were generated using this [P5.js sketch](https://editor.p5js.org/kfahn/sketches/vugGJY9Gm), downloaded, and then uploaded to Google Drive.  *Flash alert if you run the sketch!*

# %% [markdown]
# ### Mount google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# The images uploaded to Google Drive are in a folder named k_images.  I have moved them to the content folder prior to uploading to the Hugging Face Hub.

# %%
# !cp /content/gdrive/MyDrive/k_images -r /content/kaleidescope

# %%
# !apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %% [markdown]
# Install necessary libraries.

# %%
# !pip install huggingface_hub datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# You must have an access token to push a dataset to the Hugging Face Hub.

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !mkdir -p kaleidescope

# %%
from datasets import load_dataset
dataset = load_dataset("imagefolder", data_dir="kaleidescope")
# Out:
# Resolving data files:   0%|          | 0/418 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset.push_to_hub("kfahn/kaleidescope")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/kfahn/kaleidescope/commit/4c945af8bbed888275ac28ae2900a4acaa206478', commit_message='Upload dataset', commit_description='', oid='4c945af8bbed888275ac28ae2900a4acaa206478', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ### You can also create a dataset from a GIF using the following code.

# %%
# importing Image class from PIL package
from PIL import Image, ImageSequence

import cv2
import numpy as np
import imageio
#from imageio import

# # Open the GIF file
gif_path = '/content/gdrive/MyDrive/julia-2.gif'
gif = Image.open(gif_path)

# Extract individual frames from the GIF.
frames = [frame.copy() for frame in ImageSequence.Iterator(gif)]

for i, frame in enumerate(frames):
    png_path = f'/content/julia/img_{i}.png'
    frame.save(png_path, format='PNG')
